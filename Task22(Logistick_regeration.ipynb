# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithsamiksha/Model_Training/blob/main/Task22(Logistick_regeration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6654c574-6ca9-414f-96c3-8f92695771d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6654c574-6ca9-414f-96c3-8f92695771d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = 'heart - heart.csv'
df= pd.read_csv(filepath)
print(df)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
#Q1
data scaling
X = df.drop(columns=["HeartDisease"], axis = 1)
Y = df['HeartDisease']
print("Input Features:")
print(X)
print("Output Features:")
print(Y)

#one hot encoding
cat_cols = X.select_dtypes(include="object").columns
print(cat_cols)

X = pd.get_dummies(X, columns=cat_cols)
X.head()
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_F  Sex_M  \
# 0   40        140          289          0    172      0.0  False   True
# 1   49        160          180          0    156      1.0   True  False
# 2   37        130          283          0     98      0.0  False   True
# 3   48        138          214          0    108      1.5   True  False
# 4   54        150          195          0    122      0.0  False   True
#
#    ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0              False               True              False             False
# 1              False              False               True             False
# 2              False               True              False             False
# 3               True              False              False             False
# ...

# %%
cat_cols = X.select_dtypes(include="object").columns
print(cat_cols)

X = pd.get_dummies(X, columns=cat_cols)
X.head()
# Out:
# Index([], dtype='object')
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_F  Sex_M  \
# 0   40        140          289          0    172      0.0  False   True
# 1   49        160          180          0    156      1.0   True  False
# 2   37        130          283          0     98      0.0  False   True
# 3   48        138          214          0    108      1.5   True  False
# 4   54        150          195          0    122      0.0  False   True
#
#    ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0              False               True              False             False
# 1              False              False               True             False
# 2              False               True              False             False
# 3               True              False              False             False
# 4              False              False               True             False
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.20,
    random_state=42
)
print("X_train :", X_train.shape)
print("X_test :", X_test.shape)
print("Y_train :", Y_train.shape)
print("Y_test :", Y_test.shape)
# Out:
# X_train : (734, 20)
# X_test : (184, 20)
# Y_train : (734,)
# Y_test : (184,)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, Y_train)
# print("Model Train sucessfully")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Q4
y_pred = model.predict(X_test)
print("Actual Values")
print(Y_test.head(10))
print()
print("Predicted Values")
print(y_pred[:10])
# Out:
# Actual Values
# 668    0
# 30     1
# 377    1
# 535    1
# 807    0
# 793    1
# 363    1
# 583    0
# 165    1
# 483    1
# Name: HeartDisease, dtype: int64
#
# Predicted Values
# [0 0 1 1 0 1 1 0 1 1]

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, y_pred)

print(cm)

TN, FP, FN, TP = cm.ravel()

print("True Negative : ", TN)
print("False Positive : ", FP)
print("False Negative : ", FN)
print("True Positive : ", TP)
# Out:
# [[67 10]
#  [17 90]]
# True Negative :  67
# False Positive :  10
# False Negative :  17
# True Positive :  90

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

print("Accuracy : ", accuracy_score(Y_test, y_pred))
print("Precision : ", precision_score(Y_test, y_pred))
print("Recall : ", recall_score(Y_test, y_pred))
print("F1 Score : ",f1_score(Y_test, y_pred))
print()

print(classification_report(Y_test, y_pred))
# Out:
# Accuracy :  0.8532608695652174
# Precision :  0.9
# Recall :  0.8411214953271028
# F1 Score :  0.8695652173913043
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        77
#            1       0.90      0.84      0.87       107
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %% [markdown]
# ##KNN Regression Algorithum

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

model_KNN = KNeighborsClassifier(n_neighbors = 5)
model_KNN.fit(X_train, Y_train)

print("Accuracy Score Of K-Nearest Neighbors(5):")
pred_KNN = model.predict(X_test)
accuracy_score(pred_KNN, Y_test)
# Out:
# Accuracy Score Of K-Nearest Neighbors(5):
# 0.8532608695652174

# %%
#Training the model
model_KNN = KNeighborsClassifier(n_neighbors=3)
model_KNN.fit(X_train, Y_train)

#finding accuracy score
print("Accuracy Score of K-Nearest Neighbors(3):")
pred_KNN = model.predict(X_test)
accuracy_score(pred_KNN, Y_test)
# Out:
# Accuracy Score of K-Nearest Neighbors(3):
# 0.8532608695652174

# %%
#Traingn Model
model_KNN = KNeighborsClassifier(n_neighbors = 7)
model_KNN.fit(X_train, Y_train)

#Finding accuracy score
print("Accuracy Score of K-Nearest Neighbors(7):")
pred_KNN = model.predict(X_test)
accuracy_score(pred_KNN, Y_test)
# Out:
# Accuracy Score of K-Nearest Neighbors(7):
# 0.8532608695652174

# %% [markdown]
# ##Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model_NB = GaussianNB()
model_NB.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import(
    classification_report,
    confusion_matrix
)

# Predict using the Naive Bayes model
pred_NB = model_NB.predict(X_test)

cm = confusion_matrix(
    Y_test,
    pred_NB
  )
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[70  7]
#  [18 89]]

# %%
#classification report
report = classification_report(
    Y_test,
    pred_NB
)
print("Classification Report:")
print(report)

#accuracy score
print("Accuracy Score of Naive Bayes:")
accuracy_score(pred_NB, Y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85        77
#            1       0.93      0.83      0.88       107
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.87      0.86       184
# weighted avg       0.87      0.86      0.86       184
#
# Accuracy Score of Naive Bayes:
# 0.8641304347826086

# %%
comparison = pd.DataFrame(
    results,
    columns=[
        "Algorithum",
        "Accuracy",
        "Precision",
        "Recall",
        "F1 Score"
    ]
)
comparison
# Out:
#             Algorithum  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression  0.853261   0.900000  0.841121  0.869565
# 1  K-Nearest Neighbors  0.663043   0.731959  0.663551  0.696078
# 2          Naive Bayes  0.864130   0.927083  0.831776  0.876847

# %%
# import joblib
# joblib.dump(model, "heart_model.pkl")
# joblib.dump(X.columns.tolist(), "columns.pkl")

# %%
# from google.colab import files
# files.download("heart_model.pkl")
# files.download("columns.pkl")
# # files.download("scaler.pkl")
